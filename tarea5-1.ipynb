# %%
"""
    se importan los directorios necesarios
"""
# %pylab inline
import matplotlib.pyplot as plt
import numpy as np
from numpy import pi
from scipy.fftpack import fft, fftfreq
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
"""
    se carga el archivo deseado
"""
archivo=np.loadtxt(open("sampled+ma0844az_1-1+_data.txt","r"))

# %%
"""
    tamano del archivo
    datos representa el numero de mediciones
"""

datos=shape(archivo)[1]
datos
# Out:
# 24

# %%
s0=archivo[:,0]
s1=archivo[:,1]

# %%
"""
segnal 1

"""
plot(s0)
plot(s1)

# %%
"""
se grafican las 24 senales
"""
for i in range(datos):
    si=archivo[:,i]
    plot(si)

# %%
"""
se hace la fft de las senales y se guarda en n=datos arreglos posibles
"""
dt=1
fft_x = fft(s0) / datos # FFT Normalized
freq = fftfreq(datos, dt) # Recuperamos las frecuencias

plt.plot(np.abs(fft_x),label="fourier")
plt.plot(freq,label="frecuencias")
legend()

#se grafica la transformada de la senal 0
print shape(fft_x),shape(freq)
# Out:
# (400,) (24,)

# %%
"""
 se halla el espectro de potencias de cada senal como la norma de los datos dados por la transformada
"""
abso=empty(datos)
for i in range(datos):
        abso[i]=np.abs(s0[i])
        
print abso
# Out:
# [   0.         19.140624   12.011718    8.984375   38.183592    8.007812
#    22.070311    6.738281   17.480468   15.039062   48.730466   21.289061
#    74.023434    4.101562    0.878906   27.441405  233.78905    61.035153
#   167.187491    7.8125      3.613281   11.132812   23.242186    7.519531]

# %%
"""
    se grafica cada senal (la norma) contra la funcion
"""
plot(np.abs(s0))

# %%
"""
se restan las senales originales contra sus espectros de pontencias y se guarda sus diferencias en un arreglo
"""
for i in range(datos):
    0

# %%
"""
    parte B:
    
    se halla la normal al cuadrado de cada senal y se toman las senales con las normas mas altas, se guardan las posiciones
    
"""
mayores=empty(0)
for i in range(datos):
    posicion =1
    if(np.abs(s0[1]))<np.abs(s0[i]):
        posicion=i
        mayores=np.append(mayores,posicion)

# %%
"""
    SE RECONSTRUYTEN LAS SENALES
"""
